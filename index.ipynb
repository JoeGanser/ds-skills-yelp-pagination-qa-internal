# %% [markdown]
# # API Pagination
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination. Without further ado, let's take a look in practice.

# %%
import requests
import pandas as pd

# %%
client_id = 'hDqGOvJx3yOoGBy9OuwSJw'
api_key = 'Eo7fz3n3VDHlU5uv6N6DUXrDUya5WYcXoMsda4Mj6D-EAdxE6QTDLItu61PkSUf0Lxjm4-jtjSS4Sp7tDNFvZbZFkJ9fqQK_SDNt8d2fUuoxq2cH62VtWhwFml7bW3Yx'

term = 'Mexican'
location = 'Astoria NY'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "jeWIYbgBho9vBDhc5S1xvg", "alias": "holy-guacamole-astoria", "name": "Holy Guacamole", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Di8o5LhA8pEK51sYr2rb2A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/holy-guacamole-astoria?adjust_creative=hDqGOvJx3yOoGBy9OuwSJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hDqGOvJx3yOoGBy9OuwSJw", "review_count": 127, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 40.756621, "longitude": -73.929336}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "3555 31st St", "address2": "", "address3": "", "city": "Astoria", "zip_code": "11106", "country": "US", "state": "NY", "display_address": ["3555 31st St", "Astoria, NY 11106"]}, "phone": "+19178327261", "display_phone": "(917) 832-7261", "distance": 1290.4274875130448}, {"id": "AUyKmFjpaVLwc3awfUnqgQ", "alias": "chela

# %% [markdown]
# # Previewing the Results
#
# As before, let's briefly investigate the top level strucutre of our JSON response.

# %%
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# Navigating down a level, we might be curious how many restaurants fit our criteria:

# %%
response.json()['total']
# Out:
# 672

# %% [markdown]
# Now of those, we have only retrieved the first 10 results (the search limit we provided.) As the documentation describes, this defaults to 20, and can be up to 50. Observe:

# %%
print(len(response.json()['businesses']))
# Out:
# 10

# %% [markdown]
# Recall that we can also turn this into our usual Pandas DataFrame:

# %%
df = pd.DataFrame(response.json()['businesses'])
print(len(df))
df.head()
# Out:
# 10
#                                          alias  \
# 0                       holy-guacamole-astoria
# 1                   chela-and-garnacha-astoria
# 2                      de-mole-astoria-astoria
# 3                mi-espiguita-taqueria-astoria
# 4  maizal-restaurant-and-tequila-bar-astoria-2
#
#                                           categories  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 1  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]
# 4  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 40.756621, 'longitude': -73.929336}  (917) 832-7261
# 1  {'latitude': 40.7557171543477, 'longitude': -7...  (917) 832-6876
# 2  {'latitude': 40.7625999, 'longitude': -73.9129...  (718) 777-1655
# 3  {'latitude': 40.7612033639422, 'longitude': -7...  (718) 777-5648
# 4   {'latitude': 40.759331, 'longitude': -73.926035}  (718) 406-9431
#
#       distance                      id  \
# 0  1290.427488  jeWIYbgBho9vBDhc5S1xvg
# 1  1316.297661  AUyKmFjpaVLwc3awfUnqgQ
# 2   918.092772  jzVv_21473lAMYXIhVbuTA
# 3   714.301080  yvva7IYpD6J7OfKlCdQrkw
# 4   900.451091  QIsFsiOP3H_NkgeWST7GPA
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/Di8o5L...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/ChVbA1...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/v8jXvZ...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/_bPuQu...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/VOGwDm...      False
#
#                                             location  \
# 0  {'address1': '3555 31st St', 'address2': '', '...
# 1  {'address1': '33-09 36th Ave', 'address2': '',...
# 2  {'address1': '4220 30th Ave', 'address2': '', ...
# 3  {'address1': '32-44 31st St', 'address2': '', ...
# 4  {'address1': '3207 34th Ave', 'address2': None...
#
#                               name         phone price  rating  review_count  \
# 0                   Holy Guacamole  +19178327261    $$     4.0           127
# 1                 Chela & Garnacha  +19178326876    $$     4.5           312
# 2                  De Mole Astoria  +17187771655    $$     4.0           329
# 3            Mi Espiguita Taqueria  +17187775648     $     4.5           101
# 4  Maizal Restaurant & Tequila Bar  +17184069431    $$     4.0           267
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/holy-guacamole-astori...
# 1  [pickup, delivery]  https://www.yelp.com/biz/chela-and-garnacha-as...
# 2  [pickup, delivery]  https://www.yelp.com/biz/de-mole-astoria-astor...
# 3  [pickup, delivery]  https://www.yelp.com/biz/mi-espiguita-taqueria...
# 4  [pickup, delivery]  https://www.yelp.com/biz/maizal-restaurant-and...

# %% [markdown]
# We could easily change our request slightly to retrieve a larger number at a time.

# %%
# client_id = #your id here
# api_key = #your key here

term = 'Mexican'
location = 'Astoria NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "jeWIYbgBho9vBDhc5S1xvg", "alias": "holy-guacamole-astoria", "name": "Holy Guacamole", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Di8o5LhA8pEK51sYr2rb2A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/holy-guacamole-astoria?adjust_creative=hDqGOvJx3yOoGBy9OuwSJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hDqGOvJx3yOoGBy9OuwSJw", "review_count": 127, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 40.756621, "longitude": -73.929336}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "3555 31st St", "address2": "", "address3": "", "city": "Astoria", "zip_code": "11106", "country": "US", "state": "NY", "display_address": ["3555 31st St", "Astoria, NY 11106"]}, "phone": "+19178327261", "display_phone": "(917) 832-7261", "distance": 1290.4274875130448}, {"id": "AUyKmFjpaVLwc3awfUnqgQ", "alias": "chela

# %% [markdown]
# We still have the same number of matching results, but this time have been given the first 50:

# %%
response.json()['total']
# Out:
# 671

# %%
print(len(response.json()['businesses']))
# Out:
# 50

# %% [markdown]
# If we want to retrieve more of the results, we page through them by using the offset parameter:

# %%
# client_id = #your id here
# api_key = #your key here

term = 'Mexican'
location = 'Astoria NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT,
                'offset': 50
            }
response2 = requests.get(url, headers=headers, params=url_params)
print(response2)
print(type(response2.text))
print(response2.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "DY2wlHlgC5eHITs-d5rT4w", "alias": "panchos-new-york-2", "name": "Panchos", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/vwfG2x08lpXbqe3sybnT-Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/panchos-new-york-2?adjust_creative=hDqGOvJx3yOoGBy9OuwSJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hDqGOvJx3yOoGBy9OuwSJw", "review_count": 54, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.8015, "longitude": -73.96534}, "transactions": [], "price": "$", "location": {"address1": "964 Amsterdam Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10025", "country": "US", "state": "NY", "display_address": ["964 Amsterdam Ave", "New York, NY 10025"]}, "phone": "+12123165400", "display_phone": "(212) 316-5400", "distance": 5288.3093583250375}, {"id": "bHJWjEg_sGjrlSHIOX6Mqg", "alias": "two-liz

# %% [markdown]
# # Practice
#
# With that, you should have the basics to retrive the full result set!

# %% [markdown]
# ## API Call Function
#
# Use the example above to write a function to retrieve all of the results (up to the maximum 1000 provided by Yelp) for a given search. Your function should then return the results for these as a single Pandas dataframe.

# %%
#Your code here
def retrieve(term, location, search_limit):
    url = 'https://api.yelp.com/v3/businesses/search'

    headers = {
        'Authorization': 'Bearer {}'.format(api_key),
        }

    url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
    response = requests.get(url, headers=headers, params=url_params)
    return pd.DataFrame(response.json()['businesses'])

df=retrieve('Mexican','Astoria NY',1000)
# Out:
#                                                alias  \
# 0                             holy-guacamole-astoria
# 1                         chela-and-garnacha-astoria
# 2                            de-mole-astoria-astoria
# 3                      mi-espiguita-taqueria-astoria
# 4        maizal-restaurant-and-tequila-bar-astoria-2
# 5                             los-portales-astoria-2
# 6                                     tacuba-astoria
# 7                        mezquite-restaurant-astoria
# 8                 homemade-taqueria-long-island-city
# 9        las-catrinas-mexican-bar-and-eatery-astoria
# 10               athens-grill-and-sports-bar-astoria
# 11                     el-mero-mero-long-island-city
# 12                  frescos-cantina-long-island-city
# 13                                 la-cabana-astoria
# 14                     twisted-mexican-grill-astoria
# 15             los-amigos-mexican-restaurant-astoria
# 16                                  mojave-astoria-2
# 17  emilias-pizza-and-authentic-mexican-food-astoria
# 18                         el-rey-restaurant-astoria
# 19                  el-mariachi-restaurant-astoria-2
# 20             el-cafetal-mexican-restaurant-astoria
# 21                               orale-tacos-astoria
# 22                             st-james-deli-astoria
# 23                         cruz-mexican-deli-astoria
# 24                      hidalgo-mexican-food-astoria
# 25                     lunera-modern-mexican-astoria
# 26                   el-rey-del-taco-truck-astoria-2
# 27                                 swick-2-astoria-2
# 28                              tacos-mexico-astoria
# 29                           manjares-mexico-astoria
# 30                         bistro-casa-azul-new-york
# 31                           fresca-tortilla-astoria
# 32         las-margaritas-astoria-restaurant-astoria
# 33                      noche-de-margaritas-new-york
# 34                                 la-vecina-astoria
# 35                  lalys-restaurant-jackson-heights
# 36                               calexico-new-york-5
# 37                  juquila-kitchen-and-bar-queens-2
# 38                                 la-chonas-astoria
# 39                               chihuahua-sunnyside
# 40                        fresco-tortillas-astoria-4
# 41                          casa-mexicana-new-york-2
# 42   josefinas-mexican-restaurant-long-island-city-2
# 43                salvatoria-kitchen-and-bar-astoria
# 44                taqueria-coatzingo-jackson-heights
# 45                 gordos-cantina-long-island-city-2
# 46                                el-compita-astoria
# 47                juquila-mexican-cuisine-elmhurst-2
# 48                           aztoria-cantina-astoria
# 49                     casa-enrique-long-island-city
#
#                                            categories  \
# 0   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 1   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 2          [{'alias': 'mexican', 'title': 'Mexican'}]
# 3          [{'alias': 'mexican', 'title': 'Mexican'}]
# 4   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 5          [{'alias': 'mexican', 'title': 'Mexican'}]
# 6   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 7   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 8              [{'alias': 'tacos', 'title': 'Tacos'}]
# 9   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 10         [{'alias': 'mexican', 'title': 'Mexican'}]
# 11         [{'alias': 'mexican', 'title': 'Mexican'}]
# 12  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 13  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...
# 14         [{'alias': 'mexican', 'title': 'Mexican'}]
# 15  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 16  [{'alias': 'southern', 'title': 'Southern'}, {...
# 17  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 18         [{'alias': 'mexican', 'title': 'Mexican'}]
# 19         [{'alias': 'mexican', 'title': 'Mexican'}]
# 20         [{'alias': 'mexican', 'title': 'Mexican'}]
# 21             [{'alias': 'tacos', 'title': 'Tacos'}]
# 22         [{'alias': 'mexican', 'title': 'Mexican'}]
# 23         [{'alias': 'mexican', 'title': 'Mexican'}]
# 24         [{'alias': 'mexican', 'title': 'Mexican'}]
# 25  [{'alias': 'latin', 'title': 'Latin American'}...
# 26  [{'alias': 'foodtrucks', 'title': 'Food Trucks...
# 27  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 28         [{'alias': 'mexican', 'title': 'Mexican'}]
# 29         [{'alias': 'mexican', 'title': 'Mexican'}]
# 30         [{'alias': 'mexican', 'title': 'Mexican'}]
# 31  [{'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'a...
# 32  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 33         [{'alias': 'mexican', 'title': 'Mexican'}]
# 34  [{'alias': 'latin', 'title': 'Latin American'}...
# 35  [{'alias': 'newamerican', 'title': 'American (...
# 36  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 37  [{'alias': 'newmexican', 'title': 'New Mexican...
# 38  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 39         [{'alias': 'mexican', 'title': 'Mexican'}]
# 40         [{'alias': 'mexican', 'title': 'Mexican'}]
# 41         [{'alias': 'mexican', 'title': 'Mexican'}]
# 42         [{'alias': 'mexican', 'title': 'Mexican'}]
# 43  [{'alias': 'salvadoran', 'title': 'Salvadoran'...
# 44         [{'alias': 'mexican', 'title': 'Mexican'}]
# 45         [{'alias': 'mexican', 'title': 'Mexican'}]
# 46         [{'alias': 'mexican', 'title': 'Mexican'}]
# 47         [{'alias': 'mexican', 'title': 'Mexican'}]
# 48  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...
# 49         [{'alias': 'mexican', 'title': 'Mexican'}]
#
#                                           coordinates   display_phone  \
# 0    {'latitude': 40.756621, 'longitude': -73.929336}  (917) 832-7261
# 1   {'latitude': 40.7557171543477, 'longitude': -7...  (917) 832-6876
# 2   {'latitude': 40.7625999, 'longitude': -73.9129...  (718) 777-1655
# 3   {'latitude': 40.7612033639422, 'longitude': -7...  (718) 777-5648
# 4    {'latitude': 40.759331, 'longitude': -73.926035}  (718) 406-9431
# 5   {'latitude': 40.7631768211379, 'longitude': -7...  (718) 204-6736
# 6      {'latitude': 40.75585, 'longitude': -73.92447}  (718) 786-2727
# 7       {'latitude': 40.76167, 'longitude': -73.9109}  (718) 255-1722
# 8   {'latitude': 40.7546939084048, 'longitude': -7...  (718) 255-1349
# 9   {'latitude': 40.7614214682633, 'longitude': -7...  (917) 745-0969
# 10  {'latitude': 40.7671808396101, 'longitude': -7...  (718) 777-5366
# 11  {'latitude': 40.753834323302, 'longitude': -73...  (718) 392-2444
# 12     {'latitude': 40.76837, 'longitude': -73.93303}  (347) 808-7338
# 13     {'latitude': 40.76564, 'longitude': -73.91929}  (718) 267-7113
# 14  {'latitude': 40.772422, 'longitude': -73.9264379}
# 15  {'latitude': 40.7744827270508, 'longitude': -7...  (718) 726-8708
# 16  {'latitude': 40.7753290076368, 'longitude': -7...  (718) 545-4100
# 17  {'latitude': 40.7662621, 'longitude': -73.9150...  (347) 730-4632
# 18     {'latitude': 40.77137, 'longitude': -73.92198}  (718) 545-2292
# 19  {'latitude': 40.7611304286653, 'longitude': -7...  (718) 545-4039
# 20  {'latitude': 40.7702872, 'longitude': -73.9183...  (718) 956-9519
# 21  {'latitude': 40.7689108, 'longitude': -73.9256...  (718) 545-1212
# 22  {'latitude': 40.75843584113, 'longitude': -73....  (718) 482-7835
# 23     {'latitude': 40.75824, 'longitude': -73.91822}  (718) 545-0319
# 24  {'latitude': 40.7632870632524, 'longitude': -7...  (917) 832-6783
# 25  {'latitude': 40.7582236, 'longitude': -73.9194...  (718) 726-9857
# 26      {'latitude': 40.77613, 'longitude': -73.9107}  (917) 484-0689
# 27  {'latitude': 40.7564825, 'longitude': -73.9254...  (718) 786-6096
# 28     {'latitude': 40.75914, 'longitude': -73.92015}  (718) 545-5888
# 29  {'latitude': 40.7572483, 'longitude': -73.9155...  (718) 429-8933
# 30     {'latitude': 40.79659, 'longitude': -73.93229}  (917) 805-0803
# 31  {'latitude': 40.7757870486376, 'longitude': -7...  (718) 278-7666
# 32  {'latitude': 40.7594468, 'longitude': -73.9195...  (718) 777-1707
# 33  {'latitude': 40.7801018, 'longitude': -73.9497...  (212) 289-5195
# 34   {'latitude': 40.76232, 'longitude': -73.9165699}  (718) 433-9399
# 35  {'latitude': 40.747207, 'longitude': -73.8897241}  (718) 433-9906
# 36     {'latitude': 40.77259, 'longitude': -73.95588}  (347) 967-5955
# 37      {'latitude': 40.7532, 'longitude': -73.93436}  (718) 482-0033
# 38  {'latitude': 40.7593333, 'longitude': -73.9193...  (718) 204-2406
# 39  {'latitude': 40.7425222545862, 'longitude': -7...  (347) 531-0954
# 40     {'latitude': 40.75618, 'longitude': -73.92941}  (718) 267-9536
# 41  {'latitude': 40.7989892, 'longitude': -73.966955}  (212) 222-3151
# 42     {'latitude': 40.76114, 'longitude': -73.94065}  (917) 943-4355
# 43     {'latitude': 40.76142, 'longitude': -73.92486}  (718) 777-2829
# 44  {'latitude': 40.7471912668812, 'longitude': -7...  (718) 424-1977
# 45  {'latitude': 40.7512226, 'longitude': -73.9407...  (917) 947-9208
# 46      {'latitude': 40.7589, 'longitude': -73.92601}  (718) 472-9066
# 47     {'latitude': 40.74727, 'longitude': -73.88318}  (718) 458-0104
# 48  {'latitude': 40.7561834, 'longitude': -73.9214...  (718) 361-6535
# 49  {'latitude': 40.743404338358, 'longitude': -73...  (347) 448-6040
#
#        distance                      id  \
# 0   1290.427488  jeWIYbgBho9vBDhc5S1xvg
# 1   1316.297661  AUyKmFjpaVLwc3awfUnqgQ
# 2    918.092772  jzVv_21473lAMYXIhVbuTA
# 3    714.301080  yvva7IYpD6J7OfKlCdQrkw
# 4    900.451091  QIsFsiOP3H_NkgeWST7GPA
# 5    654.452199  6rM-N1SBbKPC7DWZNg5awQ
# 6   1229.351705  EHUNrnIgnhwTnpOm3gEESg
# 7   1112.460071  fjE_lpKblhrN_48X2ca-7w
# 8   1436.590901  7RgdHGMY9Xa2Ur5y7vSBZQ
# 9    642.525771  6AJwsgXr7YwsqneGVAdgzw
# 10    42.777637  yqU1-chsjix3T4EMY2MyxA
# 11  1457.114073  anBWvFPOce4nl3qLX-H6Rg
# 12   927.218713  zNcDCPiUsE5aT6jyaCVtmA
# 13   280.560883  9tlYA026rvZ0m6OBUeZX7w
# 14   711.474181  iw5iI-jFXnDZaeiGt4Weaw
# 15  1181.745009  9qOUxAQD6Tasr9TVUlSvdg
# 16  1272.483200  jFYEsw6_4y4VMpSVB863sw
# 17   617.059287  a9rBsBs6DFNbsKvAmbq3BA
# 18   498.972433  Fp2QuKOu_zCjOxbyCLfnjw
# 19   647.727753  hyKnC3_a86vaY2iZUkygWw
# 20   494.597826  QbDy2I6ENbHP-B89tH0sUQ
# 21   367.443148  BRqPr7YpcQCu23e5i__Frw
# 22   975.840443  0tzK7l-DWDpG5UrYKL_mxw
# 23  1018.119732  5VjJtOBOOnZRx4KC71IpXQ
# 24  1676.674727  uGUXV74PbdcYeHEqntDh2w
# 25   986.258835  2ewrI499NSsA1sNX30K5Dg
# 26  1411.639322  veeKjzzHsO9e4wKLxpuhtQ
# 27  1188.832717  4EGq0GMAJwGIrfhVg4PxVw
# 28   873.986101  A0nCLU0qBly0AUm-pvgNXw
# 29  1208.576669  6NBXf3fOJYL365PoaD2qAA
# 30  3410.236440  3iegS9M-EMbkhaPV2rsovg
# 31  1427.125113  oDrjaOCWxTGxJ1C8kViocg
# 32   857.448061  3M6CsWQ_FIAzpxnuqq_eHw
# 33  2759.294057  ci0-GO_iMb0NdTCUYWjocQ
# 34   696.082386  GepWuSFEGuFzE8U1fYFOXQ
# 35  3502.832417  hYk1RkElIG5rWI4ywbi-BA
# 36  2907.985852  7bD22UAtH56ikWYslOSIQg
# 37  1829.388617  JnOYZqzRBHkEB_mvMXph_g
# 38   874.273703  -xa6FYrKd98HQaVDu96JyA
# 39  2744.443959  uvcEo61aL2F8e4PCzwZsYg
# 40  1334.969887  ofyC683l9tTvkXKbmOXiEw
# 41  5189.459656  XO6IbZn2oxonPrfcXHK4HA
# 42  1681.057332  4wDGKf3dsSo2b3svJHh-qw
# 43   641.816668  47_jHPl3p4-OYGCVLy2ZIA
# 44  3518.227621  Yilk_Ucz4L6w9EmvAS2gHg
# 45  2341.450622  Guy0Mow5rqt4a3RDMRTY5g
# 46   940.062045  fjMKWJumHK2utmoqPRtgNA
# 47  3943.906941  vIDX92ttk7H-266e1Qo7RA
# 48  1181.605403  aj-cNy6I_1vp_hZ5UKQkbg
# 49  3762.278679  dgaNriM1VdI2nGochhHE_g
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/Di8o5L...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/ChVbA1...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/v8jXvZ...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/_bPuQu...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/VOGwDm...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/w1OHgt...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/Q6jPz4...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/L7_SD1...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/uqLokK...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/qRziMI...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/GkwwzL...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/GLJ1RH...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/YHpy53...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/4GjjeE...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/_R1UvX...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/PdTDz2...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/5AS8pD...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/zDBdHp...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/fTW_Vm...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/rgV0Tf...      False
# 20  https://s3-media4.fl.yelpcdn.com/bphoto/2mOsPU...      False
# 21  https://s3-media2.fl.yelpcdn.com/bphoto/JmyxJ6...      False
# 22  https://s3-media1.fl.yelpcdn.com/bphoto/N0n5c9...      False
# 23  https://s3-media2.fl.yelpcdn.com/bphoto/PLnvir...      False
# 24  https://s3-media4.fl.yelpcdn.com/bphoto/SfiMxB...      False
# 25  https://s3-media2.fl.yelpcdn.com/bphoto/8ZrRc3...      False
# 26  https://s3-media2.fl.yelpcdn.com/bphoto/qsXi1U...      False
# 27  https://s3-media2.fl.yelpcdn.com/bphoto/mgsppD...      False
# 28  https://s3-media2.fl.yelpcdn.com/bphoto/IrEbgn...      False
# 29  https://s3-media4.fl.yelpcdn.com/bphoto/ETsClE...      False
# 30  https://s3-media3.fl.yelpcdn.com/bphoto/PpOnPz...      False
# 31  https://s3-media4.fl.yelpcdn.com/bphoto/Qv1C69...      False
# 32  https://s3-media2.fl.yelpcdn.com/bphoto/ia7etI...      False
# 33  https://s3-media2.fl.yelpcdn.com/bphoto/leVM9D...      False
# 34  https://s3-media3.fl.yelpcdn.com/bphoto/cICxJ-...      False
# 35  https://s3-media1.fl.yelpcdn.com/bphoto/wtR6qk...      False
# 36  https://s3-media2.fl.yelpcdn.com/bphoto/1vz06a...      False
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/NGwnTb...      False
# 38  https://s3-media4.fl.yelpcdn.com/bphoto/0SgeCg...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/9JNhVS...      False
# 40  https://s3-media2.fl.yelpcdn.com/bphoto/zR5M5G...      False
# 41  https://s3-media4.fl.yelpcdn.com/bphoto/vGayD1...      False
# 42  https://s3-media2.fl.yelpcdn.com/bphoto/RFpX5Z...      False
# 43  https://s3-media2.fl.yelpcdn.com/bphoto/EY5vts...      False
# 44  https://s3-media1.fl.yelpcdn.com/bphoto/62yftE...      False
# 45  https://s3-media4.fl.yelpcdn.com/bphoto/udZjTH...      False
# 46                                                         False
# 47  https://s3-media1.fl.yelpcdn.com/bphoto/M4-sRu...      False
# 48  https://s3-media4.fl.yelpcdn.com/bphoto/kaMLkz...      False
# 49  https://s3-media4.fl.yelpcdn.com/bphoto/LEe3cl...      False
#
#                                              location  \
# 0   {'address1': '3555 31st St', 'address2': '', '...
# 1   {'address1': '33-09 36th Ave', 'address2': '',...
# 2   {'address1': '4220 30th Ave', 'address2': '', ...
# 3   {'address1': '32-44 31st St', 'address2': '', ...
# 4   {'address1': '3207 34th Ave', 'address2': None...
# 5   {'address1': '2508 Broadway', 'address2': '', ...
# 6   {'address1': '35-01 36th St', 'address2': '', ...
# 7   {'address1': '45-06 30th Ave', 'address2': '',...
# 8   {'address1': '45-09 34th Ave', 'address2': '',...
# 9   {'address1': '32-02 Broadway', 'address2': '',...
# 10  {'address1': '3011 30th Ave', 'address2': '', ...
# 11  {'address1': '35-57 38th St', 'address2': '', ...
# 12  {'address1': '12-14 31st Ave', 'address2': Non...
# 13  {'address1': '3318 30th Ave', 'address2': '', ...
# 14  {'address1': '18-33 Astoria Blvd', 'address2':...
# 15  {'address1': '2273 31st St', 'address2': '', '...
# 16  {'address1': '22-36 31st St', 'address2': '', ...
# 17  {'address1': '3705 28th Ave', 'address2': '', ...
# 18  {'address1': '25-21 Astoria Blvd', 'address2':...
# 19  {'address1': '3311 Broadway', 'address2': '', ...
# 20  {'address1': '30-19 Astoria Blvd', 'address2':...
# 21  {'address1': '23-23 30th Ave', 'address2': '',...
# 22  {'address1': '34-02 34th Ave', 'address2': '',...
# 23  {'address1': '3211 41st St', 'address2': '', '...
# 24  {'address1': '35-9 Vernon Blvd', 'address2': '...
# 25  {'address1': '3225 Steinway St', 'address2': '...
# 26  {'address1': '31ST St And Ditmars Ave', 'addre...
# 27  {'address1': '3504 35th St', 'address2': '', '...
# 28  {'address1': '32-08 38th St', 'address2': '', ...
# 29  {'address1': '4408 Broadway', 'address2': '', ...
# 30  {'address1': '343 Pleasant Ave', 'address2': '...
# 31  {'address1': '3115 Ditmars Blvd', 'address2': ...
# 32  {'address1': '38-01 Broadway', 'address2': Non...
# 33  {'address1': '1726 2nd Ave', 'address2': '', '...
# 34  {'address1': '30-66 Steinway St', 'address2': ...
# 35  {'address1': '75-19 Roosevelt Ave', 'address2'...
# 36  {'address1': '1491 2nd Ave', 'address2': '', '...
# 37  {'address1': '39-05 29th St', 'address2': None...
# 38  {'address1': '38-07 Broadway', 'address2': '',...
# 39  {'address1': '47-02 Greenpoint Ave', 'address2...
# 40  {'address1': '3112 36th Ave', 'address2': None...
# 41  {'address1': '894 Amsterdam Ave', 'address2': ...
# 42  {'address1': '36-01 10th St', 'address2': 'Fl ...
# 43  {'address1': '31-18 Broadway', 'address2': Non...
# 44  {'address1': '7605 Roosevelt Ave', 'address2':...
# 45  {'address1': '24-11 Bridge Plz N', 'address2':...
# 46  {'address1': '32-20 34th Ave', 'address2': '',...
# 47  {'address1': '40-12 83rd St', 'address2': '', ...
# 48  {'address1': '34-18 Steinway St', 'address2': ...
# 49  {'address1': '5-48 49th Ave', 'address2': '', ...
#
#                                        name         phone price  rating  \
# 0                            Holy Guacamole  +19178327261    $$     4.0
# 1                          Chela & Garnacha  +19178326876    $$     4.5
# 2                           De Mole Astoria  +17187771655    $$     4.0
# 3                     Mi Espiguita Taqueria  +17187775648     $     4.5
# 4           Maizal Restaurant & Tequila Bar  +17184069431    $$     4.0
# 5                              Los Portales  +17182046736     $     4.0
# 6                                    Tacuba  +17187862727    $$     3.5
# 7                       Mezquite Restaurant  +17182551722    $$     4.5
# 8                         Homemade Taqueria  +17182551349     $     4.0
# 9         Las Catrinas Mexican Bar & Eatery  +19177450969    $$     4.0
# 10                Athens Grill & Sports Bar  +17187775366     $     4.0
# 11                             El Mero Mero  +17183922444    $$     4.5
# 12                         Fresco's Cantina  +13478087338    $$     4.5
# 13                                La Cabana  +17182677113     $     4.0
# 14                    Twisted Mexican Grill                   $     4.5
# 15            Los Amigos Mexican Restaurant  +17187268708    $$     3.0
# 16                                   Mojave  +17185454100    $$     3.5
# 17  Emilia's Pizza & Authentic Mexican Food  +13477304632     $     4.5
# 18                        El Rey Restaurant  +17185452292    $$     3.5
# 19                   El Mariachi Restaurant  +17185454039     $     3.5
# 20            El Cafetal Mexican Restaurant  +17189569519    $$     3.5
# 21                              Orale Tacos  +17185451212     $     4.0
# 22                            St James Deli  +17184827835     $     4.5
# 23                        Cruz Mexican Deli  +17185450319     $     4.5
# 24                     Hidalgo Mexican Food  +19178326783    $$     4.0
# 25                    Lunera Modern Mexican  +17187269857    $$     4.0
# 26                    El Rey Del Taco Truck  +19174840689     $     4.5
# 27                                  Swick 2  +17187866096     $     4.0
# 28                             Tacos Mexico  +17185455888     $     3.0
# 29                          Manjares Mexico  +17184298933   NaN     4.0
# 30                         Bistro Casa Azul  +19178050803   NaN     5.0
# 31                          Fresca Tortilla  +17182787666     $     3.0
# 32        Las Margaritas Astoria Restaurant  +17187771707    $$     2.5
# 33                      Noche De Margaritas  +12122895195    $$     4.0
# 34                                La Vecina  +17184339399    $$     4.5
# 35                        Laly's Restaurant  +17184339906   NaN     5.0
# 36                                 Calexico  +13479675955    $$     4.0
# 37                  Juquila Kitchen and Bar  +17184820033    $$     4.0
# 38                               La Chona's  +17182042406   NaN     4.5
# 39                                Chihuahua  +13475310954    $$     4.5
# 40                         Fresco Tortillas  +17182679536     $     3.0
# 41                            Casa Mexicana  +12122223151    $$     4.0
# 42            Josefina's Mexican Restaurant  +19179434355   NaN     4.5
# 43                 Salvatoria Kitchen & Bar  +17187772829    $$     4.5
# 44                       Taqueria Coatzingo  +17184241977     $     4.0
# 45                          Gordo's Cantina  +19179479208    $$     4.0
# 46                               El Compita  +17184729066    $$     5.0
# 47                  Juquila Mexican Cuisine  +17184580104    $$     4.0
# 48                          Aztoria Cantina  +17183616535   NaN     4.0
# 49                             Casa Enrique  +13474486040    $$     4.0
#
#     review_count                                transactions  \
# 0            127                          [delivery, pickup]
# 1            312                          [delivery, pickup]
# 2            329                          [delivery, pickup]
# 3            101                          [delivery, pickup]
# 4            267                          [delivery, pickup]
# 5            218                          [delivery, pickup]
# 6            568                          [delivery, pickup]
# 7            239                          [delivery, pickup]
# 8            292                          [delivery, pickup]
# 9            198                          [delivery, pickup]
# 10           179                                          []
# 11            40                          [delivery, pickup]
# 12           121  [delivery, restaurant_reservation, pickup]
# 13            38                                          []
# 14            30                          [delivery, pickup]
# 15           115                          [delivery, pickup]
# 16           644                          [delivery, pickup]
# 17            37                          [delivery, pickup]
# 18            70                          [delivery, pickup]
# 19           219                          [delivery, pickup]
# 20            74                          [delivery, pickup]
# 21            31                          [delivery, pickup]
# 22            72                                          []
# 23             9                                          []
# 24            19                          [delivery, pickup]
# 25            79                    [restaurant_reservation]
# 26           458                                          []
# 27            30                          [delivery, pickup]
# 28            89                          [delivery, pickup]
# 29             5                          [delivery, pickup]
# 30            18                                          []
# 31            93                          [delivery, pickup]
# 32           231                          [delivery, pickup]
# 33           293                          [delivery, pickup]
# 34            86                          [delivery, pickup]
# 35            36                          [delivery, pickup]
# 36           479                          [delivery, pickup]
# 37            61                          [delivery, pickup]
# 38             6                          [delivery, pickup]
# 39           114                          [delivery, pickup]
# 40            42                          [delivery, pickup]
# 41           166                          [delivery, pickup]
# 42             3                          [delivery, pickup]
# 43           122                          [delivery, pickup]
# 44           383                                          []
# 45           164                          [delivery, pickup]
# 46             1                                          []
# 47           140                          [delivery, pickup]
# 48             5                                          []
# 49           976                                  [delivery]
#
#                                                   url
# 0   https://www.yelp.com/biz/holy-guacamole-astori...
# 1   https://www.yelp.com/biz/chela-and-garnacha-as...
# 2   https://www.yelp.com/biz/de-mole-astoria-astor...
# 3   https://www.yelp.com/biz/mi-espiguita-taqueria...
# 4   https://www.yelp.com/biz/maizal-restaurant-and...
# 5   https://www.yelp.com/biz/los-portales-astoria-...
# 6   https://www.yelp.com/biz/tacuba-astoria?adjust...
# 7   https://www.yelp.com/biz/mezquite-restaurant-a...
# 8   https://www.yelp.com/biz/homemade-taqueria-lon...
# 9   https://www.yelp.com/biz/las-catrinas-mexican-...
# 10  https://www.yelp.com/biz/athens-grill-and-spor...
# 11  https://www.yelp.com/biz/el-mero-mero-long-isl...
# 12  https://www.yelp.com/biz/frescos-cantina-long-...
# 13  https://www.yelp.com/biz/la-cabana-astoria?adj...
# 14  https://www.yelp.com/biz/twisted-mexican-grill...
# 15  https://www.yelp.com/biz/los-amigos-mexican-re...
# 16  https://www.yelp.com/biz/mojave-astoria-2?adju...
# 17  https://www.yelp.com/biz/emilias-pizza-and-aut...
# 18  https://www.yelp.com/biz/el-rey-restaurant-ast...
# 19  https://www.yelp.com/biz/el-mariachi-restauran...
# 20  https://www.yelp.com/biz/el-cafetal-mexican-re...
# 21  https://www.yelp.com/biz/orale-tacos-astoria?a...
# 22  https://www.yelp.com/biz/st-james-deli-astoria...
# 23  https://www.yelp.com/biz/cruz-mexican-deli-ast...
# 24  https://www.yelp.com/biz/hidalgo-mexican-food-...
# 25  https://www.yelp.com/biz/lunera-modern-mexican...
# 26  https://www.yelp.com/biz/el-rey-del-taco-truck...
# 27  https://www.yelp.com/biz/swick-2-astoria-2?adj...
# 28  https://www.yelp.com/biz/tacos-mexico-astoria?...
# 29  https://www.yelp.com/biz/manjares-mexico-astor...
# 30  https://www.yelp.com/biz/bistro-casa-azul-new-...
# 31  https://www.yelp.com/biz/fresca-tortilla-astor...
# 32  https://www.yelp.com/biz/las-margaritas-astori...
# 33  https://www.yelp.com/biz/noche-de-margaritas-n...
# 34  https://www.yelp.com/biz/la-vecina-astoria?adj...
# 35  https://www.yelp.com/biz/lalys-restaurant-jack...
# 36  https://www.yelp.com/biz/calexico-new-york-5?a...
# 37  https://www.yelp.com/biz/juquila-kitchen-and-b...
# 38  https://www.yelp.com/biz/la-chonas-astoria?adj...
# 39  https://www.yelp.com/biz/chihuahua-sunnyside?a...
# 40  https://www.yelp.com/biz/fresco-tortillas-asto...
# 41  https://www.yelp.com/biz/casa-mexicana-new-yor...
# 42  https://www.yelp.com/biz/josefinas-mexican-res...
# 43  https://www.yelp.com/biz/salvatoria-kitchen-an...
# 44  https://www.yelp.com/biz/taqueria-coatzingo-ja...
# 45  https://www.yelp.com/biz/gordos-cantina-long-i...
# 46  https://www.yelp.com/biz/el-compita-astoria?ad...
# 47  https://www.yelp.com/biz/juquila-mexican-cuisi...
# 48  https://www.yelp.com/biz/aztoria-cantina-astor...
# 49  https://www.yelp.com/biz/casa-enrique-long-isl...

# %% [markdown]
# ### Pseudocode outline:
#
# The function should take in url paramaters in some form. From there, the first call should check the number of results and make successive API calls using the offset parameter to cycle through these results. Each response should be stored as a DataFrame which will then be stitched together.
#
# Warning: Making too many API calls can lead to errors. Most APIs require you to slow down your requests to a manageable limit. Make sure to use the time.sleep() method from the time package to make some brief pauses (~5 seconds is more then sufficient) between successive calls.

# %% [markdown]
# ## Neighborhood ______ Restaurants
#
# Use your function above to retrieve all of the restaurants for a particular cuisine in a neighborhood of your choice.

# %%
#Your code here

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
#Your code here

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved.

# %%
#Your code here
